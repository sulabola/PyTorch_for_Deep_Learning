# %% [markdown]
# ### Pandas

# %% [markdown]
# Pandas = Panel Data
#
# It is an open-source library for data analysis. It is built directly on NumPy.

# %% [markdown]
# **Series**

# %% [markdown]
# Similar to NumPy array with index and data with named index.

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
mylist = [10,20,30]
arr = np.array(mylist)
arr
# Out:
# array([10, 20, 30])

# %%
### Create a dictionary

d = {'a':10,'b':20,'c':30}
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data=mylist)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr)

### No differences except the data type
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(data=arr, index=labels)

### A series with named index. Data can be numeric/categorical/...
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(data = ['a',0.5,'c'])
# Out:
# 0      a
# 1    0.5
# 2      c
# dtype: object

# %%
ser1 = pd.Series(data = [1,2,3,4], index=['USA','Germany','USSR','Japan'])
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
### Use of named index

ser1['USSR']
# Out:
# 3

# %%
ser2 = pd.Series(data = [1,4,5,6], index=['USA','Germany','Italy','Japan'])
ser2
# Out:
# USA        1
# Germany    4
# Italy      5
# Japan      6
# dtype: int64

# %%
### Can perform operations with multiple series. It performs operations based on the named index.

ser1 + ser2
# Out:
# Germany     6.0
# Italy       NaN
# Japan      10.0
# USA         2.0
# USSR        NaN
# dtype: float64
